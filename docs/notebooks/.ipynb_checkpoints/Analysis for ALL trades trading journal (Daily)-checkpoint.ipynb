# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pdb
import datetime

# %% [markdown]
# Parsing .xlsx

# %%
DF = pd.read_excel("/Users/ernesto/Google Drive/WORKING_FX/TRADE_BOT/06_06_2020/DAILY/allpairs.merged.xlsx")

# %% [markdown]
# * Number of records per instrument:

# %%
my_tab = pd.crosstab(index=DF['id'], columns="count")
print(my_tab)
# Out:
# col_0        count
# id
# AUD_CAD.bot     74
# AUD_CHF.bot     83
# AUD_JPY.bot     74
# AUD_NZD.bot     68
# AUD_USD.bot     52
# CAD_CHF.bot     80
# CAD_JPY.bot     86
# CHF_JPY.bot     79
# EUR_AUD.bot     56
# EUR_CAD.bot     65
# EUR_CHF.bot     38
# EUR_GBP.bot     63
# EUR_JPY.bot     55
# EUR_NZD.bot     51
# GBP_AUD.bot     37
# GBP_CHF.bot     76
# GBP_JPY.bot     42
# GBP_NZD.bot     17
# GBP_USD.bot     66
# NZD_CAD.bot     97
# NZD_JPY.bot     79
# NZD_USD.bot     88
# USD_CAD.bot     64
# USD_CHF.bot     79
# USD_JPY.bot     68

# %% [markdown]
# * Number of trades per outcome:

# %%
my_tab = pd.crosstab(index=DF['outcome'], columns="count")
print(my_tab)
# Out:
# col_0    count
# outcome
# failure    979
# success    658

# %% [markdown]
# * Frequency per outcome:

# %%
print(pd.crosstab(DF['outcome'], columns="freq").apply(lambda r: r/r.sum(), axis=0))
# Out:
# col_0        freq
# outcome
# failure  0.598045
# success  0.401955

# %% [markdown]
# * Frequency of outcome per currency

# %%
print(pd.crosstab(DF['outcome'], DF['id']).apply(lambda r: r/r.sum(), axis=0))
# Out:
# id       AUD_CAD.bot  AUD_CHF.bot  AUD_JPY.bot  AUD_NZD.bot  AUD_USD.bot  \
# outcome
# failure     0.648649      0.53012     0.581081     0.676471     0.519231
# success     0.351351      0.46988     0.418919     0.323529     0.480769
#
# id       CAD_CHF.bot  CAD_JPY.bot  CHF_JPY.bot  EUR_AUD.bot  EUR_CAD.bot  ...  \
# outcome                                                                   ...
# failure       0.5375     0.511628     0.607595        0.625     0.584615  ...
# success       0.4625     0.488372     0.392405        0.375     0.415385  ...
#
# id       GBP_CHF.bot  GBP_JPY.bot  GBP_NZD.bot  GBP_USD.bot  NZD_CAD.bot  \
# outcome
# failure     0.605263     0.666667     0.823529     0.545455     0.742268
# success     0.394737     0.333333     0.176471     0.454545     0.257732
#
# id       NZD_JPY.bot  NZD_USD.bot  USD_CAD.bot  USD_CHF.bot  USD_JPY.bot
# outcome
# failure     0.531646     0.579545     0.609375     0.582278     0.558824
# success     0.468354     0.420455     0.390625     0.417722     0.441176
#
# [2 rows x 25 columns]

# %% [markdown]
# * Frequency of outcome per type

# %%
print(pd.crosstab(DF['outcome'], DF['type']).apply(lambda r: r/r.sum(), axis=0))
# Out:
# type         long     short
# outcome
# failure  0.615758  0.580049
# success  0.384242  0.419951

# %% [markdown]
# # Analysis of trades

# %% [markdown]
# ## Transforming
# We will transform the 2 outcome labels to digits

# %%
transl_dict={ 
        'S':1,
        'F':0,
        'success' : 1,
        'failure' : 0,
        True:1, 
        False:0
    }
def digit_binary(x,transl_dict,name):
    '''
    This function will replace the values in categorical
    binary variables by 1 and 0
    
    Parameters
    ----------
    transl_dict: dict
                 Keys will be the old categorical names and Values
                 will be 1 and 0. For example:
                 transl_dict={ 
                            'S':1,
                            'F':0, 
                            True:1, 
                            False:0
                            }
    name: str
          Name of the column to modify
        
    Returns
    -------
    The new label for the categorical variable
    '''
    return transl_dict[x[name]]

DF['outcome']=DF.apply(digit_binary,axis=1,transl_dict=transl_dict, name='outcome')

# %%
DF.shape
# Out:
# (1637, 24)

# %% [markdown]
# ## start of trade

# %% [markdown]
# Let's create a new discrete variable with year of trade

# %%
DF['year'] = DF['start'].apply(lambda x: x.year)

# %% [markdown]
# * Number of trades per year:

# %%
my_tab = pd.crosstab(index=DF['year'], columns="count")
print(my_tab)
# Out:
# col_0  count
# year
# 2007      91
# 2008      62
# 2009      68
# 2010     156
# 2011     119
# 2012     153
# 2013     141
# 2014      95
# 2015     122
# 2016     139
# 2017     163
# 2018     178
# 2019     124
# 2020      26

# %% [markdown]
# * Frequency of outcome per year

# %%
print(pd.crosstab(DF['outcome'], DF['year']).apply(lambda r: r/r.sum(), axis=0))
# Out:
# year         2007      2008      2009      2010      2011      2012      2013  \
# outcome
# 0        0.604396  0.580645  0.544118  0.608974  0.588235  0.568627  0.560284
# 1        0.395604  0.419355  0.455882  0.391026  0.411765  0.431373  0.439716
#
# year     2014      2015      2016      2017      2018      2019      2020
# outcome
# 0         0.6  0.581967  0.582734  0.705521  0.589888  0.620968  0.538462
# 1         0.4  0.418033  0.417266  0.294479  0.410112  0.379032  0.461538

# %% [markdown]
# ## SLdiff

# %%
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)

ax = sns.boxplot(x="outcome", y="SLdiff", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="SLdiff", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'SLdiff': 'mean'})
# Out:
#              SLdiff
# outcome
# 0        106.279367
# 1        109.931459

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'SLdiff': 'median'})
# Out:
#          SLdiff
# outcome
# 0        108.30
# 1        111.75

# %% [markdown]
# ## pips_c_trend

# %% [raw]
# fig, ax = plt.subplots(figsize=(4, 3), dpi=200)
#
# ax = sns.boxplot(x="outcome", y="pips_c_trend", data=DF, ax=ax)
#
# sns.swarmplot(x="outcome", y="SLdiff", data=DF, color="red", size=3, ax=ax)

# %% [raw]
# * Mean for each category

# %% [raw]
# DF.groupby("outcome").agg({'SLdiff': 'mean'})

# %% [raw]
# * Median for each category

# %% [raw]
# DF.groupby("outcome").agg({'SLdiff': 'median'})

# %% [markdown]
# ## entry_onrsi

# %%
DFonrsi = DF.loc[DF['entry_onrsi']==True]

# %% [markdown]
# The number of trades per outcome

# %%
my_tab = pd.crosstab(index=DFonrsi['outcome'], columns="count")
print(my_tab)
# Out:
# col_0    count
# outcome
# 0          100
# 1           11

# %% [markdown]
# ## max_min_rsi

# %% [markdown]
# ### RSI in oversold

# %% [markdown]
# Let's analyse values that are above/below the oversold thresholds. For this I 've analysed
# a range of thresholds and calculated the outcome categories frequency for this range

# %%
def get_freq_for_rsi(DF, rsi_long, rsi_short):
    """
    Function to get the frequency for categories
    of outcome variable for diff RSI thresholds
    
    Parameters
    ----------
    DF : pandas dataframe
    rsi_long : int
               RSI threshold for long trades
    rsi_short : int
                RSI threshold for short trades
    """
    print("processing with rsi_long:{0}; rsi_short:{1}".format(rsi_long,rsi_short))
    DFshort=DF.loc[(DF['max_min_rsi']>=rsi_short)& (DF['type']=="short")]
    DFlong=DF.loc[(DF['max_min_rsi']<=rsi_long)& (DF['type']=="long")]
    tomerge=[DFshort, DFlong]
    DFover=pd.concat(tomerge)
    my_tab = pd.crosstab(index=DFover['outcome'], columns="count")
    print(my_tab)
    freqs=pd.crosstab(DFover['outcome'], columns="freq").apply(lambda r: r/r.sum(), axis=0)
    print(freqs)
    return freqs

# %%
no_short = 60
no_long = 40
while no_short <= 80 and no_long>=20:
    freqs=get_freq_for_rsi(DF ,rsi_long=no_long, rsi_short=no_short)
    no_short=no_short+1
    no_long=no_long-1
# Out:
# processing with rsi_long:40; rsi_short:60
# col_0    count
# outcome
# 0          779
# 1          509
# col_0        freq
# outcome
# 0        0.604814
# 1        0.395186
# processing with rsi_long:39; rsi_short:61
# col_0    count
# outcome
# 0          753
# 1          487
# col_0        freq
# outcome
# 0        0.607258
# 1        0.392742
# processing with rsi_long:38; rsi_short:62
# col_0    count
# outcome
# 0          708
# 1          457
# col_0        freq
# outcome
# 0        0.607725
# 1        0.392275
# processing with rsi_long:37; rsi_short:63
# col_0    count
# outcome
# 0          667
# 1          426
# col_0        freq
# outcome
# 0        0.610247
# 1        0.389753
# processing with rsi_long:36; rsi_short:64
# col_0    count
# outcome
# 0          622
# 1          388
# col_0        freq
# outcome
# 0        0.615842
# 1        0.384158
# processing with rsi_long:35; rsi_short:65
# col_0    count
# outcome
# 0          571
# 1          356
# col_0        freq
# outcome
# 0        0.615965
# 1        0.384035
# processing with rsi_long:34; rsi_short:66
# col_0    count
# outcome
# 0          512
# 1          328
# col_0        freq
# outcome
# 0        0.609524
# 1        0.390476
# processing with rsi_long:33; rsi_short:67
# col_0    count
# outcome
# 0          455
# 1          289
# col_0        freq
# outcome
# 0        0.611559
# 1        0.388441
# processing with rsi_long:32; rsi_short:68
# col_0    count
# outcome
# 0          415
# 1          258
# col_0        freq
# outcome
# 0        0.616642
# 1        0.383358
# processing with rsi_long:31; rsi_short:69
# col_0    count
# outcome
# 0          367
# 1          231
# col_0        freq
# outcome
# 0        0.613712
# 1        0.386288
# processing with rsi_long:30; rsi_short:70
# col_0    count
# outcome
# 0          320
# 1          198
# col_0        freq
# outcome
# 0        0.617761
# 1        0.382239
# processing with rsi_long:29; rsi_short:71
# col_0    count
# outcome
# 0          281
# 1          170
# col_0       freq
# outcome
# 0        0.62306
# 1        0.37694
# processing with rsi_long:28; rsi_short:72
# col_0    count
# outcome
# 0          239
# 1          148
# col_0        freq
# outcome
# 0        0.617571
# 1        0.382429
# processing with rsi_long:27; rsi_short:73
# col_0    count
# outcome
# 0          199
# 1          123
# col_0        freq
# outcome
# 0        0.618012
# 1        0.381988
# processing with rsi_long:26; rsi_short:74
# col_0    count
# outcome
# 0          166
# 1          102
# col_0        freq
# outcome
# 0        0.619403
# 1        0.380597
# processing with rsi_long:25; rsi_short:75
# col_0    count
# outcome
# 0          129
# 1           86
# col_0    freq
# outcome
# 0         0.6
# 1         0.4
# processing with rsi_long:24; rsi_short:76
# col_0    count
# outcome
# 0           99
# 1           72
# col_0        freq
# outcome
# 0        0.578947
# 1        0.421053
# processing with rsi_long:23; rsi_short:77
# col_0    count
# outcome
# 0           77
# 1           58
# col_0       freq
# outcome
# 0        0.57037
# 1        0.42963
# processing with rsi_long:22; rsi_short:78
# col_0    count
# outcome
# 0           56
# 1           47
# col_0        freq
# outcome
# 0        0.543689
# 1        0.456311
# processing with rsi_long:21; rsi_short:79
# col_0    count
# outcome
# 0           46
# 1           31
# col_0        freq
# outcome
# 0        0.597403
# 1        0.402597
# processing with rsi_long:20; rsi_short:80
# col_0    count
# outcome
# 0           30
# 1           19
# col_0        freq
# outcome
# 0        0.612245
# 1        0.387755

# %% [markdown]
# ### RSI not in oversold

# %%
DFnotinrsi=DF.loc[(DF['max_min_rsi']>30)& (DF['max_min_rsi']<70)]

# %%
DFnotinrsi.shape
# Out:
# (1119, 25)

# %% [markdown]
# * Number of trades per outcome:

# %%
my_tab = pd.crosstab(index=DFnotinrsi['outcome'], columns="count")
print(my_tab)
# Out:
# col_0    count
# outcome
# 0          659
# 1          460

# %% [markdown]
# * Frequency

# %%
print(pd.crosstab(DFnotinrsi['outcome'], columns="freq").apply(lambda r: r/r.sum(), axis=0))
# Out:
# col_0        freq
# outcome
# 0        0.588919
# 1        0.411081

# %% [markdown]
# ## trend_i

# %%
DF['trend_i']= pd.to_datetime(DF['trend_i'])
DF['start'] = pd.to_datetime(DF['start'])

# %%
DF['diff_trendi']=(DF['start']-DF['trend_i'])
DF['diff_trendi']=DF['diff_trendi'].apply(lambda x: x.days)
# Out:
# 0        98
# 1        36
# 2        30
# 3        17
# 4        17
#        ...
# 1632     20
# 1633     25
# 1634     67
# 1635     60
# 1636    180
# Name: diff_trendi, Length: 1637, dtype: int64

# %% [markdown]
# Now, let's examine the distribution of this newly created diff variable in the 2 outcome categories

# %%
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)

ax = sns.boxplot(x="outcome", y="diff_trendi", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="diff_trendi", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'diff_trendi': 'mean'})
# Out:
#          diff_trendi
# outcome
# 0          38.590398
# 1          38.325228

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'diff_trendi': 'median'})
# Out:
#          diff_trendi
# outcome
# 0                 28
# 1                 28

# %% [markdown]
# * Binning data
# Let's bin the data into a certain number of categories

# %%
max_v=max(DF['diff_trendi'])

custom_bins_array = np.arange(0, max_v, 20)

DF['diff_cat']=pd.cut(DF['diff_trendi'], np.around(custom_bins_array))

# %%
DF_counts = (DF.groupby(['outcome'])['diff_cat']
                  .value_counts(normalize=True)
                  .rename('percentage')
                  .mul(100)
                  .reset_index()
                  .sort_values('diff_cat'))

sns.set(rc={'figure.figsize':(30,9.27)})

p = sns.barplot(x="diff_cat", y="percentage", hue='outcome', data=DF_counts)

# %% [markdown]
# ## Pivots
# This quantitative discrete variable is used for representing the number of times the price has tested this level.

# %% [markdown]
# ## last time
# This datetime variable represents the last time the price was over/below the entry price level. The first to do is to create a new datetime variable representing the difference (in days) between the entry datetime (start column) and the last time datetime.¶

# %% [markdown]
# First thing we need to do is to convert the variables `start` and `lasttime` to Datetime class

# %%
DF['lasttime']= pd.to_datetime(DF['lasttime'])
DF['start'] = pd.to_datetime(DF['start'])

# %%
DF['diff_lasttime']=(DF['start']-DF['lasttime'])
DF['diff_lasttime']=DF['diff_lasttime'].apply(lambda x: x.days)

# %% [markdown]
# Now, let's examine the distribution of this newly created diff variable in the 2 outcome categories

# %%
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)

ax = sns.boxplot(x="outcome", y="diff_lasttime", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="diff_lasttime", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'diff_lasttime': 'mean'})
# Out:
#          diff_lasttime
# outcome
# 0           322.673684
# 1           346.138599

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'diff_lasttime': 'median'})
# Out:
#          diff_lasttime
# outcome
# 0                  120
# 1                  130

# %% [markdown]
# * Binning data
# Let's bin the data into a certain number of categories

# %%
max_v=max(DF['diff_lasttime'])

custom_bins_array = np.arange(0, max_v, 150)

DF['diff_cat']=pd.cut(DF['diff_lasttime'], np.around(custom_bins_array))

# %%
DF_counts = (DF.groupby(['outcome'])['diff_cat']
                  .value_counts(normalize=True)
                  .rename('percentage')
                  .mul(100)
                  .reset_index()
                  .sort_values('diff_cat'))

sns.set(rc={'figure.figsize':(30,9.27)})

p = sns.barplot(x="diff_cat", y="percentage", hue='outcome', data=DF_counts)

# %% [markdown]
# ## Pivots
# This quantitative discrete variable is used for representing the number of times the price has tested this level.

# %%
import ast
import pdb

def get_no_pivots(x):
    pivots = ast.literal_eval(x['pivots'])
    return len(pivots)

DF['no_pivots']=DF.apply(get_no_pivots,axis=1)

# %% [markdown]
# Let's start comparing the distribution of this variable for the different categories of the outcome variable.§m

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'no_pivots': 'mean'})
# Out:
#          no_pivots
# outcome
# 0         4.821053
# 1         4.858420

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'no_pivots': 'median'})
# Out:
#          no_pivots
# outcome
# 0                4
# 1                4

# %% [markdown]
# * Binning data
# Let's bin the data into a certain number of categories

# %%
max_v=max(DF['no_pivots'])

custom_bins_array = np.arange(0, max_v, 1)

DF['bounces peak_cat']=pd.cut(DF['no_pivots'], np.around(custom_bins_array))

# %%
 DF_counts = (DF.groupby(['outcome'])['bounces peak_cat']
                  .value_counts(normalize=True)
                  .rename('percentage')
                  .mul(100)
                  .reset_index()
                  .sort_values('bounces peak_cat'))

sns.set(rc={'figure.figsize':(30,9.27)})

p = sns.barplot(x="bounces peak_cat", y="percentage", hue='outcome', data=DF_counts)

# %% [markdown]
# * Custom bins

# %%
DF['no_pivots_cat'] = pd.cut(x=DF['no_pivots'], bins=[0,2,4,6,8,50], labels=['1-2','3-4','5-6','7-8','>=9'])

# %%
DF_counts = (DF.groupby(['outcome'])['no_pivots_cat']
                  .value_counts(normalize=True)
                  .rename('percentage')
                  .mul(100)
                  .reset_index()
                  .sort_values('no_pivots_cat'))

sns.set(rc={'figure.figsize':(30,9.27)})

p = sns.barplot(x="no_pivots_cat", y="percentage", hue='outcome', data=DF_counts)

# %% [markdown]
# ## pivots_lasttime
# This quantitative discrete variable is used for representing the number of times the price has tested this level since last_time. Let's start comparing the distribution of this variable for the different categories of the outcome variable.¶

# %%
import ast
import pdb

def get_no_pivots_lasttime(x):
    pivots = ast.literal_eval(x['pivots_lasttime'])
    return len(pivots)

DF['no_pivots_lasttime']=DF.apply(get_no_pivots_lasttime,axis=1)

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'no_pivots_lasttime': 'mean'})
# Out:
#          no_pivots_lasttime
# outcome
# 0                  1.050718
# 1                  0.952310

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'no_pivots_lasttime': 'median'})
# Out:
#          no_pivots_lasttime
# outcome
# 0                         1
# 1                         1

# %% [markdown]
# * Binning data
# Let's bin the data into a certain number of categories. `np.arange(0,max_v,1)` where 1 controls the width of each bin

# %%
max_v=max(DF['no_pivots_lasttime'])

custom_bins_array = np.arange(0, max_v, 1)

DF['bounces peak_cat']=pd.cut(DF['no_pivots_lasttime'], np.around(custom_bins_array))

# %%
DF_counts = (DF.groupby(['outcome'])['bounces peak_cat']
                  .value_counts(normalize=True)
                  .rename('percentage')
                  .mul(100)
                  .reset_index()
                  .sort_values('bounces peak_cat'))

sns.set(rc={'figure.figsize':(25,4.27)})

p = sns.barplot(x="bounces peak_cat", y="percentage", hue='outcome', data=DF_counts)

# %% [markdown]
# * Custom bins

# %%
DF['no_pivots_lasttime_cat'] = pd.cut(x=DF['no_pivots_lasttime'], 
                                      bins=[-1,1,3,50], labels=['0-1','2-3','>=4'])

# %%
DF_counts = (DF.groupby(['outcome'])['no_pivots_lasttime_cat']
                  .value_counts(normalize=True)
                  .rename('percentage')
                  .mul(100)
                  .reset_index()
                  .sort_values('no_pivots_lasttime_cat'))

sns.set(rc={'figure.figsize':(30,9.27)})

p = sns.barplot(x="no_pivots_lasttime_cat", y="percentage", hue='outcome', data=DF_counts)

# %% [markdown]
# ## total score

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'total_score': 'mean'})
# Out:
#          total_score
# outcome
# 0        4026.181148
# 1        4062.458718

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'total_score': 'median'})
# Out:
#          total_score
# outcome
# 0             3759.7
# 1             3752.8

# %% [markdown]
# Now, let's examine the distribution of this newly created diff variable in the 2 outcome categories

# %%
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)

ax = sns.boxplot(x="outcome", y="total_score", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="total_score", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# ## score_lasttime

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'score_lasttime': 'mean'})
# Out:
#          score_lasttime
# outcome
# 0            758.899713
# 1            733.107303

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'score_lasttime': 'median'})
# Out:
#          score_lasttime
# outcome
# 0                 368.7
# 1                 276.4

# %% [markdown]
# Now, let's examine the distribution of this newly created diff variable in the 2 outcome categories

# %%
fig, ax = plt.subplots(figsize=(4, 3), dpi=200)

ax = sns.boxplot(x="outcome", y="score_lasttime", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="score_lasttime", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# ## score_pivot

# %% [markdown]
# Mean score per pivot

# %%
sns.set(font_scale=0.5)


fig, ax = plt.subplots(figsize=(3, 3), dpi=200)


sns.boxplot(x="outcome", y="score_pivot", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="score_pivot", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'score_pivot': 'mean'})
# Out:
#          score_pivot
# outcome
# 0         951.454464
# 1         956.532578

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'score_pivot': 'median'})
# Out:
#          score_pivot
# outcome
# 0         803.822222
# 1         823.675000

# %% [markdown]
# ## score_pivot_lasttime

# %% [markdown]
# Mean score per pivot after lasttime

# %%
sns.set(font_scale=0.5)


fig, ax = plt.subplots(figsize=(3, 3), dpi=200)


sns.boxplot(x="outcome", y="score_pivot_lasttime", data=DF, ax=ax)

sns.swarmplot(x="outcome", y="score_pivot_lasttime", data=DF, color="red", size=3, ax=ax)

# %% [markdown]
# * Mean for each category

# %%
DF.groupby("outcome").agg({'score_pivot_lasttime': 'mean'})
# Out:
#          score_pivot_lasttime
# outcome
# 0                  433.583874
# 1                  431.207750

# %% [markdown]
# * Median for each category

# %%
DF.groupby("outcome").agg({'score_pivot_lasttime': 'median'})
# Out:
#          score_pivot_lasttime
# outcome
# 0                       329.5
# 1                       275.8
